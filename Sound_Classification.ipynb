# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import librosa
import librosa.display
import tensorflow as tf
import IPython.display as ipd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm
from tqdm.auto import tqdm
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , Activation , Dropout

# %% [markdown]
# # Analysing Data Type and Format

# %%
df = pd.read_csv("D:/Coding/Python/PROJECTS/Stability/Sound/UrbanSound8K.csv")
df.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3  \
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %% [markdown]
# #### Using Librosa to analyse random sound sample - SPECTROGRAM

# %%
dat1, sampling_rate1 = librosa.load('D:/Coding/Python/PROJECTS/Stability/Sound/fold5/100032-3-0-0.wav')
dat2, sampling_rate2 = librosa.load('D:/Coding/Python/PROJECTS/Stability/Sound/fold5/100263-2-0-117.wav')

# %% [markdown]
# ##### dat1

# %%
plt.figure(figsize=(20, 20))
D = librosa.amplitude_to_db(np.abs(librosa.stft(dat1)), ref=np.max)
plt.subplot(4, 2, 1)
librosa.display.specshow(D, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')
# Out:
# Text(0.5, 1.0, 'Linear-frequency power spectrogram')

# %% [markdown]
# ##### dat2

# %%
plt.figure(figsize=(20, 20))
D = librosa.amplitude_to_db(np.abs(librosa.stft(dat2)), ref=np.max)
plt.subplot(4, 2, 1)
librosa.display.specshow(D, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')
# Out:
# Text(0.5, 1.0, 'Linear-frequency power spectrogram')

# %%
arr = np.array(df["slice_file_name"])
fold = np.array(df["fold"])
cla = np.array(df["class"])

for i in range(192, 197, 2):
    path = 'D:/Coding/Python/PROJECTS/Stability/Sound/fold' + str(fold[i]) + '/' + arr[i]
    data, sampling_rate = librosa.load(path)
    plt.figure(figsize=(10, 10))
    D = librosa.amplitude_to_db(np.abs(librosa.stft(data)), ref=np.max)
    plt.subplot(4, 2, 1)
    librosa.display.specshow(D, y_axis='linear')
    plt.colorbar(format='%+2.0f dB')
    plt.title(cla[i])

# %% [markdown]
# # Feature Extraction and Database Building
#
# ## • Mel Spectrograms
#
# ## • MFCC

# %%
def features_extract(file):
    sample,sample_rate = librosa.load(file_name)
    feature = librosa.feature.mfcc(y=sample,sr=sample_rate,n_mfcc=50)
    scaled_feature = np.mean(feature.T,axis=0)
    return scaled_feature

extracted = []
path = 'D:/Coding/Python/PROJECTS/Stability/Sound'

for index_num,row in tqdm(df.iterrows()):
    file_name = os.path.join(path +'/'+'fold'+ str(row["fold"])+'/', str(row['slice_file_name'])).replace("\\","/")
    final_class_labels = row['class']
    data = features_extract(file_name)
    extracted.append([data,final_class_labels])
# Out:
# 0it [00:00, ?it/s]
# d:\Coding\Python\3.9\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=2048 is too large for input signal of length=1323
#   warnings.warn(
# d:\Coding\Python\3.9\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=2048 is too large for input signal of length=1103
#   warnings.warn(
# d:\Coding\Python\3.9\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=2048 is too large for input signal of length=1523
#   warnings.warn(

# %%
ext_df = pd.DataFrame(extracted,columns=['feature','class'])
ext_df
# Out:
#                                                 feature             class
# 0     [-211.93698, 62.581203, -122.81315, -60.745293...          dog_bark
# 1     [-417.0052, 99.336624, -42.995586, 51.073326, ...  children_playing
# 2     [-452.39316, 112.36253, -37.578068, 43.195866,...  children_playing
# 3     [-406.47922, 91.1966, -25.043556, 42.78452, 11...  children_playing
# 4     [-439.63873, 103.86224, -42.658787, 50.690277,...  children_playing
# ...                                                 ...               ...
# 8727  [-391.3721, 125.36239, -40.634056, 25.899754, ...          car_horn
# 8728  [-339.42715, 76.409096, -35.30988, 41.984035, ...          car_horn
# 8729  [-297.31534, 102.09026, -36.75108, 26.816488, ...          car_horn
# 8730  [-336.92386, 115.3139, -44.8471, 24.968985, -9...          car_horn
# 8731  [-307.4176, 83.30673, -25.756512, 35.44811, 4....          car_horn
#
# [8732 rows x 2 columns]

# %%
x = np.array(ext_df['feature'].tolist())
y = np.array(ext_df['class'].tolist())

# %%
le = LabelEncoder()

y = to_categorical(le.fit_transform(y))

# %% [markdown]
# #### Train - Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 42)

print("Number of training samples = ", x_train.shape[0])
print("Number of testing samples = ",x_test.shape[0])
# Out:
# Number of training samples =  6985
# Number of testing samples =  1747

# %% [markdown]
# #### ANN Model

# %%
num_labels = y.shape[1]
model = Sequential()

model.add(Dense(128, input_shape=(50,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(128))

model.add(Dense(num_labels))
model.add(Activation('softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               6528
#
#  activation (Activation)     (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  activation_1 (Activation)   (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 10)                1290
#
#  activation_3 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 139,530
# Trainable params: 139,530
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Compiling the model

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# #### Fitting the model

# %%
model.fit(
          x_train, 
          y_train, 
          batch_size=32, 
          epochs=100,
          validation_data=(x_test, y_test),
         )
# Out:
# Epoch 1/100
# 219/219 [==============================] - 6s 6ms/step - loss: 9.5606 - accuracy: 0.1343 - val_loss: 2.1949 - val_accuracy: 0.1895
# Epoch 2/100
# 219/219 [==============================] - 1s 5ms/step - loss: 2.4466 - accuracy: 0.1865 - val_loss: 2.1987 - val_accuracy: 0.1511
# Epoch 3/100
# 219/219 [==============================] - 1s 4ms/step - loss: 2.2025 - accuracy: 0.2220 - val_loss: 2.1749 - val_accuracy: 0.1523
# Epoch 4/100
# 219/219 [==============================] - 1s 4ms/step - loss: 2.0895 - accuracy: 0.2518 - val_loss: 1.9954 - val_accuracy: 0.2307
# Epoch 5/100
# 219/219 [==============================] - 1s 4ms/step - loss: 1.9790 - accuracy: 0.2880 - val_loss: 1.9001 - val_accuracy: 0.2530
# Epoch 6/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.8678 - accuracy: 0.3357 - val_loss: 1.7112 - val_accuracy: 0.3829
# Epoch 7/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.7774 - accuracy: 0.3727 - val_loss: 1.6027 - val_accuracy: 0.4001
# Epoch 8/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.6671 - accuracy: 0.4165 - val_loss: 1.4585 - val_accuracy: 0.4963
# Epoch 9/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.5936 - accuracy: 0.4415 - val_loss: 1.3705 - val_accuracy: 0.5381
# Epoch 10/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.5334 - accuracy: 0.4649 - val_loss: 1.3155 - val_accuracy: 0.5655
# Epoch 11/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.4794 - accuracy: 0.4903 - val_loss: 1.2560 - val_accuracy: 0.5902
# Epoch 12/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.4307 - accuracy: 0.5248 - val_loss: 1.2273 - val_accuracy: 0.6245
# Epoch 13/100
# 219/219 [==============================] - 1s 6ms/step - loss: 1.3659 - accuracy: 0.5427 - val_loss: 1.1410 - val_accuracy: 0.6400
# Epoch 14/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.3428 - accuracy: 0.5485 - val_loss: 1.0917 - val_accuracy: 0.6445
# Epoch 15/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2977 - accuracy: 0.5719 - val_loss: 1.0529 - val_accuracy: 0.6606
# Epoch 16/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2693 - accuracy: 0.5860 - val_loss: 1.0491 - val_accuracy: 0.6646
# Epoch 17/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2262 - accuracy: 0.5971 - val_loss: 0.9794 - val_accuracy: 0.6875
# Epoch 18/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.1817 - accuracy: 0.6087 - val_loss: 0.9879 - val_accuracy: 0.6880
# Epoch 19/100
# 219/219 [==============================] - 1s 4ms/step - loss: 1.1642 - accuracy: 0.6147 - val_loss: 0.9745 - val_accuracy: 0.6829
# Epoch 20/100
# 219/219 [==============================] - 1s 4ms/step - loss: 1.1689 - accuracy: 0.6202 - val_loss: 0.9487 - val_accuracy: 0.7069
# Epoch 21/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.1443 - accuracy: 0.6220 - val_loss: 0.9016 - val_accuracy: 0.7167
# Epoch 22/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.1101 - accuracy: 0.6394 - val_loss: 0.8988 - val_accuracy: 0.7144
# Epoch 23/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0991 - accuracy: 0.6368 - val_loss: 0.8691 - val_accuracy: 0.7218
# Epoch 24/100
# 219/219 [==============================] - 1s 6ms/step - loss: 1.0838 - accuracy: 0.6417 - val_loss: 0.8912 - val_accuracy: 0.7081
# Epoch 25/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0683 - accuracy: 0.6518 - val_loss: 0.8280 - val_accuracy: 0.7504
# Epoch 26/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0626 - accuracy: 0.6531 - val_loss: 0.8404 - val_accuracy: 0.7396
# Epoch 27/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0411 - accuracy: 0.6597 - val_loss: 0.8009 - val_accuracy: 0.7556
# Epoch 28/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0083 - accuracy: 0.6680 - val_loss: 0.8096 - val_accuracy: 0.7464
# Epoch 29/100
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0015 - accuracy: 0.6671 - val_loss: 0.8018 - val_accuracy: 0.7527
# Epoch 30/100
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0095 - accuracy: 0.6693 - val_loss: 0.7629 - val_accuracy: 0.7665
# Epoch 31/100
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0091 - accuracy: 0.6669 - val_loss: 0.7744 - val_accuracy: 0.7693
# Epoch 32/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9678 - accuracy: 0.6827 - val_loss: 0.7777 - val_accuracy: 0.7596
# Epoch 33/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9883 - accuracy: 0.6691 - val_loss: 0.7442 - val_accuracy: 0.7687
# Epoch 34/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.9332 - accuracy: 0.6961 - val_loss: 0.6974 - val_accuracy: 0.7928
# Epoch 35/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9488 - accuracy: 0.6931 - val_loss: 0.7386 - val_accuracy: 0.7831
# Epoch 36/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9603 - accuracy: 0.6868 - val_loss: 0.7166 - val_accuracy: 0.7825
# Epoch 37/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.9553 - accuracy: 0.6919 - val_loss: 0.7091 - val_accuracy: 0.7853
# Epoch 38/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9197 - accuracy: 0.7047 - val_loss: 0.6982 - val_accuracy: 0.7974
# Epoch 39/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9188 - accuracy: 0.6951 - val_loss: 0.7158 - val_accuracy: 0.7848
# Epoch 40/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9149 - accuracy: 0.6986 - val_loss: 0.6981 - val_accuracy: 0.7997
# Epoch 41/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.9061 - accuracy: 0.7012 - val_loss: 0.6803 - val_accuracy: 0.8042
# Epoch 42/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8956 - accuracy: 0.7097 - val_loss: 0.6881 - val_accuracy: 0.8025
# Epoch 43/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9046 - accuracy: 0.6974 - val_loss: 0.6874 - val_accuracy: 0.7876
# Epoch 44/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.9038 - accuracy: 0.7094 - val_loss: 0.6795 - val_accuracy: 0.7951
# Epoch 45/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.8855 - accuracy: 0.7110 - val_loss: 0.6569 - val_accuracy: 0.7956
# Epoch 46/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.8792 - accuracy: 0.7180 - val_loss: 0.6600 - val_accuracy: 0.8140
# Epoch 47/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8675 - accuracy: 0.7191 - val_loss: 0.6582 - val_accuracy: 0.8088
# Epoch 48/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8558 - accuracy: 0.7197 - val_loss: 0.6694 - val_accuracy: 0.7859
# Epoch 49/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8639 - accuracy: 0.7162 - val_loss: 0.6317 - val_accuracy: 0.8100
# Epoch 50/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8643 - accuracy: 0.7191 - val_loss: 0.6410 - val_accuracy: 0.8088
# Epoch 51/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8372 - accuracy: 0.7227 - val_loss: 0.6252 - val_accuracy: 0.8111
# Epoch 52/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8409 - accuracy: 0.7286 - val_loss: 0.6685 - val_accuracy: 0.8037
# Epoch 53/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8369 - accuracy: 0.7261 - val_loss: 0.6276 - val_accuracy: 0.8100
# Epoch 54/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8497 - accuracy: 0.7190 - val_loss: 0.6234 - val_accuracy: 0.8145
# Epoch 55/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8564 - accuracy: 0.7164 - val_loss: 0.6339 - val_accuracy: 0.8094
# Epoch 56/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8313 - accuracy: 0.7274 - val_loss: 0.6287 - val_accuracy: 0.8088
# Epoch 57/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.8346 - accuracy: 0.7293 - val_loss: 0.6298 - val_accuracy: 0.8111
# Epoch 58/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8145 - accuracy: 0.7357 - val_loss: 0.6074 - val_accuracy: 0.8140
# Epoch 59/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8105 - accuracy: 0.7389 - val_loss: 0.6183 - val_accuracy: 0.8157
# Epoch 60/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8007 - accuracy: 0.7373 - val_loss: 0.5886 - val_accuracy: 0.8208
# Epoch 61/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7944 - accuracy: 0.7343 - val_loss: 0.6209 - val_accuracy: 0.8157
# Epoch 62/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8036 - accuracy: 0.7374 - val_loss: 0.6224 - val_accuracy: 0.8122
# Epoch 63/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.8190 - accuracy: 0.7300 - val_loss: 0.6214 - val_accuracy: 0.8122
# Epoch 64/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8081 - accuracy: 0.7334 - val_loss: 0.6036 - val_accuracy: 0.8168
# Epoch 65/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8088 - accuracy: 0.7364 - val_loss: 0.6097 - val_accuracy: 0.8168
# Epoch 66/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8134 - accuracy: 0.7397 - val_loss: 0.6077 - val_accuracy: 0.8243
# Epoch 67/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8012 - accuracy: 0.7394 - val_loss: 0.5891 - val_accuracy: 0.8300
# Epoch 68/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8044 - accuracy: 0.7394 - val_loss: 0.5915 - val_accuracy: 0.8180
# Epoch 69/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.7850 - accuracy: 0.7413 - val_loss: 0.5864 - val_accuracy: 0.8346
# Epoch 70/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8027 - accuracy: 0.7437 - val_loss: 0.5839 - val_accuracy: 0.8374
# Epoch 71/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7772 - accuracy: 0.7522 - val_loss: 0.5842 - val_accuracy: 0.8248
# Epoch 72/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.7842 - accuracy: 0.7479 - val_loss: 0.5897 - val_accuracy: 0.8311
# Epoch 73/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7756 - accuracy: 0.7505 - val_loss: 0.5799 - val_accuracy: 0.8220
# Epoch 74/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7674 - accuracy: 0.7546 - val_loss: 0.6024 - val_accuracy: 0.8168
# Epoch 75/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.7725 - accuracy: 0.7539 - val_loss: 0.6096 - val_accuracy: 0.8243
# Epoch 76/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7784 - accuracy: 0.7545 - val_loss: 0.5999 - val_accuracy: 0.8334
# Epoch 77/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7649 - accuracy: 0.7475 - val_loss: 0.5504 - val_accuracy: 0.8294
# Epoch 78/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.7621 - accuracy: 0.7512 - val_loss: 0.5527 - val_accuracy: 0.8340
# Epoch 79/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7611 - accuracy: 0.7522 - val_loss: 0.5465 - val_accuracy: 0.8392
# Epoch 80/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7639 - accuracy: 0.7559 - val_loss: 0.5479 - val_accuracy: 0.8420
# Epoch 81/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7585 - accuracy: 0.7568 - val_loss: 0.5459 - val_accuracy: 0.8426
# Epoch 82/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.7491 - accuracy: 0.7598 - val_loss: 0.5832 - val_accuracy: 0.8197
# Epoch 83/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7685 - accuracy: 0.7518 - val_loss: 0.5669 - val_accuracy: 0.8311
# Epoch 84/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.7620 - accuracy: 0.7526 - val_loss: 0.5769 - val_accuracy: 0.8203
# Epoch 85/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7595 - accuracy: 0.7599 - val_loss: 0.5669 - val_accuracy: 0.8351
# Epoch 86/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7475 - accuracy: 0.7578 - val_loss: 0.5545 - val_accuracy: 0.8311
# Epoch 87/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.7540 - accuracy: 0.7585 - val_loss: 0.5811 - val_accuracy: 0.8306
# Epoch 88/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7882 - accuracy: 0.7446 - val_loss: 0.5706 - val_accuracy: 0.8403
# Epoch 89/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.7460 - accuracy: 0.7571 - val_loss: 0.5433 - val_accuracy: 0.8443
# Epoch 90/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.7617 - accuracy: 0.7536 - val_loss: 0.5518 - val_accuracy: 0.8426
# Epoch 91/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7581 - accuracy: 0.7543 - val_loss: 0.5280 - val_accuracy: 0.8432
# Epoch 92/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7690 - accuracy: 0.7513 - val_loss: 0.5577 - val_accuracy: 0.8380
# Epoch 93/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.7633 - accuracy: 0.7578 - val_loss: 0.5424 - val_accuracy: 0.8540
# Epoch 94/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7456 - accuracy: 0.7586 - val_loss: 0.5359 - val_accuracy: 0.8386
# Epoch 95/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7160 - accuracy: 0.7671 - val_loss: 0.5564 - val_accuracy: 0.8363
# Epoch 96/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.7302 - accuracy: 0.7645 - val_loss: 0.5310 - val_accuracy: 0.8466
# Epoch 97/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7136 - accuracy: 0.7641 - val_loss: 0.5565 - val_accuracy: 0.8323
# Epoch 98/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.7368 - accuracy: 0.7619 - val_loss: 0.5318 - val_accuracy: 0.8460
# Epoch 99/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.7184 - accuracy: 0.7659 - val_loss: 0.5457 - val_accuracy: 0.8369
# Epoch 100/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.7217 - accuracy: 0.7623 - val_loss: 0.5520 - val_accuracy: 0.8329

# %% [markdown]
# #### Extracting features for prediction

# %%
def extract_feature_and_print_prediction(file_name):
    audio_data, sample_rate = librosa.load(file_name) 
    fea = librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=50)
    scaled = np.mean(fea.T,axis=0)
    pred_fea = np.array([scaled])
    pred_vector = np.argmax(model.predict(pred_fea),axis=-1)
    pred_class = le.inverse_transform(pred_vector)
    print("The Predicted class is:", pred_class[0], '\n')

# %%
df
# Out:
#          slice_file_name    fsID       start         end  salience  fold
# 0       100032-3-0-0.wav  100032    0.000000    0.317551         1     5  \
# 1     100263-2-0-117.wav  100263   58.500000   62.500000         1     5
# 2     100263-2-0-121.wav  100263   60.500000   64.500000         1     5
# 3     100263-2-0-126.wav  100263   63.000000   67.000000         1     5
# 4     100263-2-0-137.wav  100263   68.500000   72.500000         1     5
# ...                  ...     ...         ...         ...       ...   ...
# 8727     99812-1-2-0.wav   99812  159.522205  163.522205         2     7
# 8728     99812-1-3-0.wav   99812  181.142431  183.284976         2     7
# 8729     99812-1-4-0.wav   99812  242.691902  246.197885         2     7
# 8730     99812-1-5-0.wav   99812  253.209850  255.741948         2     7
# 8731     99812-1-6-0.wav   99812  332.289233  334.821332         2     7
#
#       classID             class
# 0           3          dog_bark
# 1           2  children_playing
# 2           2  children_playing
# 3           2  children_playing
# 4           2  children_playing
# ...       ...               ...
# 8727        1          car_horn
# 8728        1          car_horn
# 8729        1          car_horn
# 8730        1          car_horn
# 8731        1          car_horn
#
# [8732 rows x 8 columns]

# %%
extract_feature_and_print_prediction('D:/Coding/Python/PROJECTS/Stability/Sound/fold2/100652-3-0-2.wav')
ipd.Audio('D:/Coding/Python/PROJECTS/Stability/Sound/fold2/100652-3-0-2.wav')
# Out:
# 1/1 [==============================] - 0s 156ms/step
# The Predicted class is: dog_bark
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Making a h5 file to upload to flask

# %%
import joblib
filename = 'sound_classification.h5'
joblib.dump(extract_feature_and_print_prediction, filename)
# Out:
# ['sound_classification.h5']
